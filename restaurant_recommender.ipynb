# %% [markdown]
# # Install the necessary requirements

# %%
# !pip3 install aitoai==0.4.0
# Out:
# Requirement already satisfied: aitoai==0.4.0 in c:\users\lszab\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: jsonschema~=3.0 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (3.2.0)
# Requirement already satisfied: xlrd~=1.1 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (1.2.0)
# Requirement already satisfied: requests~=2.22 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (2.24.0)
# Requirement already satisfied: ndjson>=0.2.0 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (0.3.1)
# Requirement already satisfied: pandas~=1.0; python_full_version > "3.6.0" in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (1.0.1)
# Requirement already satisfied: aiohttp~=3.4; python_version < "3.8" in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (3.7.2)
# Requirement already satisfied: argcomplete<2.0,>=1.11.1 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (1.12.1)
# Requirement already satisfied: langdetect<2.0,>=1.0.7 in c:\users\lszab\anaconda3\lib\site-packages (from aitoai==0.4.0) (1.0.8)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lszab\anaconda3\lib\site-packages (from jsonschema~=3.0->aitoai==0.4.0) (20.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\lszab\anaconda3\lib\site-packages (from jsonschema~=3.0->aitoai==0.4.0) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lszab\anaconda3\lib\site-packages (from jsonschema~=3.0->aitoai==0.4.0) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\lszab\anaconda3\lib\site-packages (from jsonschema~=3.0->aitoai==0.4.0) (50.3.0.post20201006)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\lszab\anaconda3\lib\site-packages (from jsonschema~=3.0->aitoai==0.4.0) (1.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lszab\anaconda3\lib\site-packages (from requests~=2.22->aitoai==0.4.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lszab\anaconda3\lib\site-packages (from requests~=2.22->aitoai==0.4.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lszab\anaconda3\lib\site-packages (from requests~=2.22->aitoai==0.4.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lszab\anaconda3\lib\site-packages (from requests~=2.22->aitoai==0.4.0) (1.25.10)
# Requirement already satisfied: pytz>=2017.2 in c:\users\lszab\anaconda3\lib\site-packages (from pandas~=1.0; python_full_version > "3.6.0"->aitoai==0.4.0) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lszab\anaconda3\lib\site-packages (from pandas~=1.0; python_full_version > "3.6.0"->aitoai==0.4.0) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\lszab\anaconda3\lib\site-packages (from pandas~=1.0; python_full_version > "3.6.0"->aitoai==0.4.0) (2.8.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lszab\anaconda3\lib\site-packages (from aiohttp~=3.4; python_version < "3.8"->aitoai==0.4.0) (1.6.2)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\lszab\anaconda3\lib\site-packages (from aiohttp~=3.4; python_version < "3.8"->aitoai==0.4.0) (3.7.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lszab\anaconda3\lib\site-packages (from aiohttp~=3.4; python_version < "3.8"->aitoai==0.4.0) (5.0.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\lszab\anaconda3\lib\site-packages (from aiohttp~=3.4; python_version < "3.8"->aitoai==0.4.0) (3.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lszab\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema~=3.0->aitoai==0.4.0) (3.3.0)

# %%
import pandas as pd
import numpy as np
from aito.schema import AitoStringType, AitoTextType, AitoDelimiterAnalyzerSchema, AitoTableSchema, AitoColumnLinkSchema, AitoDatabaseSchema
from aito.client import AitoClient
import aito.api as aito_api

# %%
from pathlib import Path
# Change the data folder to where you have downloaded the original data
data_folder = (Path('.') / 'data' / 'original').resolve()

# %% [markdown]
# # Load and process data files

# %% [markdown]
# ## Places files

# %% [markdown]
# ### chefmozaccepts.csv file

# %%
places_accept_df = pd.read_csv(data_folder / f'chefmozaccepts.csv')
places_accept_df
# Out:
#       placeID             Rpayment
# 0      135110                 cash
# 1      135110                 VISA
# 2      135110  MasterCard-Eurocard
# 3      135110     American_Express
# 4      135110     bank_debit_cards
# ...       ...                  ...
# 1309   132012          Diners_Club
# 1310   132002  MasterCard-Eurocard
# 1311   132002                 Visa
# 1312   132002     American_Express
# 1313   132002          Diners_Club
#
# [1314 rows x 2 columns]

# %% [markdown]
# Group the restaurant by its placeID since Aito supports multi values in a column

# %%
places_accept_df.rename(columns={'Rpayment': 'payment'}, inplace=True)
places_accept_df = places_accept_df.groupby('placeID').agg({'payment': lambda x: ';'.join(x)}).reset_index()
places_accept_df
# Out:
#      placeID                                            payment
# 0     132002  MasterCard-Eurocard;Visa;American_Express;Dine...
# 1     132012  Visa;American_Express;bank_debit_cards;Diners_...
# 2     132019  MasterCard-Eurocard;Visa;American_Express;Dine...
# 3     132023  American_Express;Japan_Credit_Bureau;bank_debi...
# 4     132024  Visa;American_Express;bank_debit_cards;Diners_...
# ..       ...                                                ...
# 610   135105                                               cash
# 611   135106                      cash;VISA;MasterCard-Eurocard
# 612   135107  cash;VISA;MasterCard-Eurocard;American_Express...
# 613   135109                                               cash
# 614   135110  cash;VISA;MasterCard-Eurocard;American_Express...
#
# [615 rows x 2 columns]

# %% [markdown]
# ### chefmozparking.csv file

# %%
places_parking_df = pd.read_csv(data_folder / f'chefmozparking.csv')
places_parking_df
# Out:
#      placeID parking_lot
# 0     135111      public
# 1     135110        none
# 2     135109        none
# 3     135108        none
# 4     135107        none
# ..       ...         ...
# 697   132024      street
# 698   132023         fee
# 699   132023      public
# 700   132012      public
# 701   132012      street
#
# [702 rows x 2 columns]

# %%
places_parking_df = places_parking_df.groupby('placeID').agg({'parking_lot': lambda x: ';'.join(x)}).reset_index()
places_parking_df
# Out:
#      placeID    parking_lot
# 0     132012  public;street
# 1     132023     fee;public
# 2     132024         street
# 3     132026            fee
# 4     132030         street
# ..       ...            ...
# 670   135107           none
# 671   135108           none
# 672   135109           none
# 673   135110           none
# 674   135111         public
#
# [675 rows x 2 columns]

# %% [markdown]
# ### chefmozcuisine.csv file

# %%
places_cuisine_df = pd.read_csv(data_folder / f'chefmozcuisine.csv')
places_cuisine_df
# Out:
#      placeID        Rcuisine
# 0     135110         Spanish
# 1     135109         Italian
# 2     135107  Latin_American
# 3     135106         Mexican
# 4     135105       Fast_Food
# ..       ...             ...
# 911   132005         Seafood
# 912   132004         Seafood
# 913   132003   International
# 914   132002         Seafood
# 915   132001   Dutch-Belgian
#
# [916 rows x 2 columns]

# %%
places_cuisine_df.rename(columns={'Rcuisine': 'cuisine'}, inplace=True)
places_cuisine_df = places_cuisine_df.groupby('placeID').agg({'cuisine': lambda x: ';'.join(x)}).reset_index()
places_cuisine_df
# Out:
#      placeID         cuisine
# 0     132001   Dutch-Belgian
# 1     132002         Seafood
# 2     132003   International
# 3     132004         Seafood
# 4     132005  French;Seafood
# ..       ...             ...
# 764   135105       Fast_Food
# 765   135106         Mexican
# 766   135107  Latin_American
# 767   135109         Italian
# 768   135110         Spanish
#
# [769 rows x 2 columns]

# %% [markdown]
# ### geoplaces2.csv file

# %%
places_geo_df = pd.read_csv(data_folder / f'geoplaces2.csv', encoding='latin-1')
places_geo_df
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# 127  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 128  0101000020957F0000B49B2E5C6E785AC12F9D58435241...
# 129  0101000020957F000090735015B84B58C1AF0DC0414698...
#
#                                name  \
# 0                   Kiku Cuernavaca
# 1                   puesto de tacos
# 2      El Rincï¿½n de San Francisco
# 3    little pizza Emilio Portes Gil
# 4                     carnitas_mata
# ..                              ...
# 125                         Chaires
# 126                      Sushi Itto
# 127                       Paniroles
# 128     Restaurant Bar Coty y Pablo
# 129                sirloin stockade
#
#                                              address             city  \
# 0                                         Revolucion       Cuernavaca
# 1             esquina santos degollado y leon guzman           s.l.p.
# 2                                    Universidad 169  San Luis Potosi
# 3                            calle emilio portes gil        victoria
# 4                             lic. Emilio portes gil         victoria
# ..                                               ...              ...
# 125                                 Ricardo B. Anaya  San Luis Potosi
# 126               Venustiano Carranza 1809 C Polanco  San Luis Potosi
# 127                                                ?                ?
# 128  Paseo de Las Fuentes 24 Pedregal de Las Fuentes         Jiutepec
# 129                                                ?                ?
#
#                state country fax  ...            alcohol   smoking_area  \
# 0            Morelos  Mexico   ?  ...  No_Alcohol_Served           none
# 1             s.l.p.  mexico   ?  ...  No_Alcohol_Served           none
# 2    San Luis Potosi  Mexico   ?  ...          Wine-Beer    only at bar
# 3         tamaulipas       ?   ?  ...  No_Alcohol_Served           none
# 4         Tamaulipas  Mexico   ?  ...  No_Alcohol_Served      permitted
# ..               ...     ...  ..  ...                ...            ...
# 125  San Luis Potosi  Mexico   ?  ...  No_Alcohol_Served  not permitted
# 126              SLP  Mexico   ?  ...  No_Alcohol_Served           none
# 127                ?       ?   ?  ...          Wine-Beer  not permitted
# 128          Morelos  Mexico   ?  ...  No_Alcohol_Served           none
# 129                ?       ?   ?  ...  No_Alcohol_Served           none
#
#     dress_code     accessibility   price                    url Rambience  \
# 0     informal  no_accessibility  medium  kikucuernavaca.com.mx  familiar
# 1     informal        completely     low                      ?  familiar
# 2     informal         partially  medium                      ?  familiar
# 3     informal        completely     low                      ?  familiar
# 4     informal        completely  medium                      ?  familiar
# ..         ...               ...     ...                    ...       ...
# 125   informal        completely  medium                      ?  familiar
# 126   informal  no_accessibility  medium      sushi-itto.com.mx  familiar
# 127   informal  no_accessibility  medium                      ?     quiet
# 128   informal        completely     low                      ?  familiar
# 129   informal        completely     low                      ?  familiar
#
#     franchise    area other_services
# 0           f  closed           none
# 1           f    open           none
# 2           f    open           none
# 3           t  closed           none
# 4           t  closed           none
# ..        ...     ...            ...
# 125         f  closed           none
# 126         f  closed           none
# 127         f  closed       Internet
# 128         f  closed           none
# 129         f  closed           none
#
# [130 rows x 21 columns]

# %%
places_geo_df.replace('?', np.nan, inplace=True)  # replace the unknown value '?' with np.Nan
places_geo_df
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# 127  0101000020957F0000A6BF695F136F5AC1DADF87B20556...
# 128  0101000020957F0000B49B2E5C6E785AC12F9D58435241...
# 129  0101000020957F000090735015B84B58C1AF0DC0414698...
#
#                                name  \
# 0                   Kiku Cuernavaca
# 1                   puesto de tacos
# 2      El Rincï¿½n de San Francisco
# 3    little pizza Emilio Portes Gil
# 4                     carnitas_mata
# ..                              ...
# 125                         Chaires
# 126                      Sushi Itto
# 127                       Paniroles
# 128     Restaurant Bar Coty y Pablo
# 129                sirloin stockade
#
#                                              address             city  \
# 0                                         Revolucion       Cuernavaca
# 1             esquina santos degollado y leon guzman           s.l.p.
# 2                                    Universidad 169  San Luis Potosi
# 3                            calle emilio portes gil        victoria
# 4                             lic. Emilio portes gil         victoria
# ..                                               ...              ...
# 125                                 Ricardo B. Anaya  San Luis Potosi
# 126               Venustiano Carranza 1809 C Polanco  San Luis Potosi
# 127                                              NaN              NaN
# 128  Paseo de Las Fuentes 24 Pedregal de Las Fuentes         Jiutepec
# 129                                              NaN              NaN
#
#                state country  fax  ...            alcohol   smoking_area  \
# 0            Morelos  Mexico  NaN  ...  No_Alcohol_Served           none
# 1             s.l.p.  mexico  NaN  ...  No_Alcohol_Served           none
# 2    San Luis Potosi  Mexico  NaN  ...          Wine-Beer    only at bar
# 3         tamaulipas     NaN  NaN  ...  No_Alcohol_Served           none
# 4         Tamaulipas  Mexico  NaN  ...  No_Alcohol_Served      permitted
# ..               ...     ...  ...  ...                ...            ...
# 125  San Luis Potosi  Mexico  NaN  ...  No_Alcohol_Served  not permitted
# 126              SLP  Mexico  NaN  ...  No_Alcohol_Served           none
# 127              NaN     NaN  NaN  ...          Wine-Beer  not permitted
# 128          Morelos  Mexico  NaN  ...  No_Alcohol_Served           none
# 129              NaN     NaN  NaN  ...  No_Alcohol_Served           none
#
#     dress_code     accessibility   price                    url Rambience  \
# 0     informal  no_accessibility  medium  kikucuernavaca.com.mx  familiar
# 1     informal        completely     low                    NaN  familiar
# 2     informal         partially  medium                    NaN  familiar
# 3     informal        completely     low                    NaN  familiar
# 4     informal        completely  medium                    NaN  familiar
# ..         ...               ...     ...                    ...       ...
# 125   informal        completely  medium                    NaN  familiar
# 126   informal  no_accessibility  medium      sushi-itto.com.mx  familiar
# 127   informal  no_accessibility  medium                    NaN     quiet
# 128   informal        completely     low                    NaN  familiar
# 129   informal        completely     low                    NaN  familiar
#
#     franchise    area other_services
# 0           f  closed           none
# 1           f    open           none
# 2           f    open           none
# 3           t  closed           none
# 4           t  closed           none
# ..        ...     ...            ...
# 125         f  closed           none
# 126         f  closed           none
# 127         f  closed       Internet
# 128         f  closed           none
# 129         f  closed           none
#
# [130 rows x 21 columns]

# %%
places_geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   placeID         130 non-null    int64
#  1   latitude        130 non-null    float64
#  2   longitude       130 non-null    float64
#  3   the_geom_meter  130 non-null    object
#  4   name            130 non-null    object
#  5   address         103 non-null    object
#  6   city            112 non-null    object
#  7   state           112 non-null    object
#  8   country         102 non-null    object
#  9   fax             0 non-null      float64
#  10  zip             56 non-null     object
#  11  alcohol         130 non-null    object
#  12  smoking_area    130 non-null    object
#  13  dress_code      130 non-null    object
#  14  accessibility   130 non-null    object
#  15  price           130 non-null    object
#  16  url             14 non-null     object
#  17  Rambience       130 non-null    object
#  18  franchise       130 non-null    object
#  19  area            130 non-null    object
#  20  other_services  130 non-null    object
# dtypes: float64(3), int64(1), object(17)
# memory usage: 21.5+ KB

# %%
# remove the "fax" and "url" column since they are mostly null
places_geo_df.drop(columns=['fax', 'url'], inplace=True)

# %% [markdown]
# #### Concatenate the restaurant dfs into a single df

# %%
from functools import reduce
places_df = reduce(lambda left,right: pd.merge(left, right, on='placeID', how='outer'), [places_accept_df, places_cuisine_df, places_parking_df, places_geo_df])
places_df.placeID = places_df.placeID.astype(str)
places_df.replace({np.nan: None}, inplace=True)
places_df
# Out:
#     placeID                                            payment  \
# 0    132002  MasterCard-Eurocard;Visa;American_Express;Dine...
# 1    132012  Visa;American_Express;bank_debit_cards;Diners_...
# 2    132019  MasterCard-Eurocard;Visa;American_Express;Dine...
# 3    132023  American_Express;Japan_Credit_Bureau;bank_debi...
# 4    132024  Visa;American_Express;bank_debit_cards;Diners_...
# ..      ...                                                ...
# 929  133041                                               None
# 930  133042                                               None
# 931  134979                                               None
# 932  135108                                               None
# 933  135111                                               None
#
#                           cuisine    parking_lot latitude longitude  \
# 0                         Seafood           None     None      None
# 1            French;Dutch-Belgian  public;street     None      None
# 2                   Dutch-Belgian           None     None      None
# 3            French;Dutch-Belgian     fee;public     None      None
# 4    Seafood;Continental-European         street     None      None
# ..                            ...            ...      ...       ...
# 929                          None           none     None      None
# 930                          None           none     None      None
# 931                          None           none     None      None
# 932                          None           none  22.1363  -100.934
# 933                          None         public     None      None
#
#                                         the_geom_meter        name  \
# 0                                                 None        None
# 1                                                 None        None
# 2                                                 None        None
# 3                                                 None        None
# 4                                                 None        None
# ..                                                 ...         ...
# 929                                               None        None
# 930                                               None        None
# 931                                               None        None
# 932  0101000020957F00008FAE40D59E4B58C112C66046D597...  Potzocalli
# 933                                               None        None
#
#                   address             city  ...   zip            alcohol  \
# 0                    None             None  ...  None               None
# 1                    None             None  ...  None               None
# 2                    None             None  ...  None               None
# 3                    None             None  ...  None               None
# 4                    None             None  ...  None               None
# ..                    ...              ...  ...   ...                ...
# 929                  None             None  ...  None               None
# 930                  None             None  ...  None               None
# 931                  None             None  ...  None               None
# 932  Carretera Central Sn  San Luis Potosi  ...  None  No_Alcohol_Served
# 933                  None             None  ...  None               None
#
#     smoking_area dress_code accessibility price Rambience franchise    area  \
# 0           None       None          None  None      None      None    None
# 1           None       None          None  None      None      None    None
# 2           None       None          None  None      None      None    None
# 3           None       None          None  None      None      None    None
# 4           None       None          None  None      None      None    None
# ..           ...        ...           ...   ...       ...       ...     ...
# 929         None       None          None  None      None      None    None
# 930         None       None          None  None      None      None    None
# 931         None       None          None  None      None      None    None
# 932         none   informal    completely   low  familiar         f  closed
# 933         None       None          None  None      None      None    None
#
#     other_services
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 929           None
# 930           None
# 931           None
# 932           none
# 933           None
#
# [934 rows x 22 columns]

# %% [markdown]
# ## User files

# %% [markdown]
# ### usercuisine file

# %%
users_cuisine_df = pd.read_csv(data_folder / 'usercuisine.csv')
users_cuisine_df
# Out:
#     userID           Rcuisine
# 0    U1001           American
# 1    U1002            Mexican
# 2    U1003            Mexican
# 3    U1004             Bakery
# 4    U1004   Breakfast-Brunch
# ..     ...                ...
# 325  U1135           Southern
# 326  U1135  Dessert-Ice_Cream
# 327  U1136            Mexican
# 328  U1137            Mexican
# 329  U1138           Pizzeria
#
# [330 rows x 2 columns]

# %%
users_cuisine_df.rename(columns={'Rcuisine': 'cuisine'}, inplace=True)
users_cuisine_df = users_cuisine_df.groupby('userID').agg({'cuisine': lambda x: '; '.join(x)}).reset_index()
users_cuisine_df
# Out:
#     userID                                            cuisine
# 0    U1001                                           American
# 1    U1002                                            Mexican
# 2    U1003                                            Mexican
# 3    U1004  Bakery; Breakfast-Brunch; Japanese; Contempora...
# 4    U1005                                           American
# ..     ...                                                ...
# 133  U1134                                            Mexican
# 134  U1135  Organic-Healthy; Steaks; Middle_Eastern; Medit...
# 135  U1136                                            Mexican
# 136  U1137                                            Mexican
# 137  U1138                                           Pizzeria
#
# [138 rows x 2 columns]

# %% [markdown]
# ### userpayment file

# %%
users_payment_df = pd.read_csv(data_folder / 'userpayment.csv')
users_payment_df
# Out:
#     userID          Upayment
# 0    U1001              cash
# 1    U1002              cash
# 2    U1003              cash
# 3    U1004              cash
# 4    U1004  bank_debit_cards
# ..     ...               ...
# 172  U1134              cash
# 173  U1135              cash
# 174  U1136              cash
# 175  U1137              cash
# 176  U1138              cash
#
# [177 rows x 2 columns]

# %%
users_payment_df.rename(columns={'Upayment': 'payment'}, inplace=True)
users_payment_df = users_payment_df.groupby('userID').agg({'payment': lambda x: '; '.join(x)}).reset_index()
users_payment_df
# Out:
#     userID                 payment
# 0    U1001                    cash
# 1    U1002                    cash
# 2    U1003                    cash
# 3    U1004  cash; bank_debit_cards
# 4    U1005                    cash
# ..     ...                     ...
# 128  U1134                    cash
# 129  U1135                    cash
# 130  U1136                    cash
# 131  U1137                    cash
# 132  U1138                    cash
#
# [133 rows x 2 columns]

# %% [markdown]
# ### userprofile file

# %%
users_profile_df = pd.read_csv(data_folder / 'userprofile.csv')
users_profile_df
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 0    U1001  22.139997 -100.978803  false      abstemious         informal
# 1    U1002  22.150087 -100.983325  false      abstemious         informal
# 2    U1003  22.119847 -100.946527  false  social drinker           formal
# 3    U1004  18.867000  -99.183000  false      abstemious         informal
# 4    U1005  22.183477 -100.959891  false      abstemious    no preference
# ..     ...        ...         ...    ...             ...              ...
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#     ambience  transport marital_status        hijos  birth_year      interest  \
# 0     family    on foot         single  independent        1989       variety
# 1     family     public         single  independent        1990    technology
# 2     family     public         single  independent        1989          none
# 3     family     public         single  independent        1940       variety
# 4     family     public         single  independent        1992          none
# ..       ...        ...            ...          ...         ...           ...
# 133   family     public         single  independent        1991       variety
# 134   family    on foot         single         kids        1988       variety
# 135  friends  car owner         single  independent        1990         retro
# 136   family     public         single  independent        1989  eco-friendly
# 137  friends     public         single  independent        1991       variety
#
#              personality  religion      activity   color  weight  budget  \
# 0      thrifty-protector      none       student   black      69  medium
# 1    hunter-ostentatious  Catholic       student     red      40     low
# 2            hard-worker  Catholic       student    blue      60     low
# 3            hard-worker      none  professional   green      44  medium
# 4      thrifty-protector  Catholic       student   black      65  medium
# ..                   ...       ...           ...     ...     ...     ...
# 133          hard-worker  Catholic       student   black      52  medium
# 134  hunter-ostentatious  Catholic       student  purple      66     low
# 135    thrifty-protector  Catholic       student   black      50     low
# 136          hard-worker  Catholic       student    blue      72     low
# 137    thrifty-protector      none       student    blue      54  medium
#
#      height
# 0      1.77
# 1      1.87
# 2      1.69
# 3      1.53
# 4      1.69
# ..      ...
# 133    1.65
# 134    1.54
# 135    1.60
# 136    1.78
# 137    1.55
#
# [138 rows x 19 columns]

# %%
users_df = reduce(lambda left,right: pd.merge(left, right, on='userID', how='outer'), [users_profile_df, users_cuisine_df, users_payment_df])
users_df.replace({np.nan: None}, inplace=True)
users_df
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 0    U1001  22.139997 -100.978803  false      abstemious         informal
# 1    U1002  22.150087 -100.983325  false      abstemious         informal
# 2    U1003  22.119847 -100.946527  false  social drinker           formal
# 3    U1004  18.867000  -99.183000  false      abstemious         informal
# 4    U1005  22.183477 -100.959891  false      abstemious    no preference
# ..     ...        ...         ...    ...             ...              ...
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#     ambience  transport marital_status        hijos  ...      interest  \
# 0     family    on foot         single  independent  ...       variety
# 1     family     public         single  independent  ...    technology
# 2     family     public         single  independent  ...          none
# 3     family     public         single  independent  ...       variety
# 4     family     public         single  independent  ...          none
# ..       ...        ...            ...          ...  ...           ...
# 133   family     public         single  independent  ...       variety
# 134   family    on foot         single         kids  ...       variety
# 135  friends  car owner         single  independent  ...         retro
# 136   family     public         single  independent  ...  eco-friendly
# 137  friends     public         single  independent  ...       variety
#
#              personality  religion      activity   color weight  budget  \
# 0      thrifty-protector      none       student   black     69  medium
# 1    hunter-ostentatious  Catholic       student     red     40     low
# 2            hard-worker  Catholic       student    blue     60     low
# 3            hard-worker      none  professional   green     44  medium
# 4      thrifty-protector  Catholic       student   black     65  medium
# ..                   ...       ...           ...     ...    ...     ...
# 133          hard-worker  Catholic       student   black     52  medium
# 134  hunter-ostentatious  Catholic       student  purple     66     low
# 135    thrifty-protector  Catholic       student   black     50     low
# 136          hard-worker  Catholic       student    blue     72     low
# 137    thrifty-protector      none       student    blue     54  medium
#
#     height                                            cuisine  \
# 0     1.77                                           American
# 1     1.87                                            Mexican
# 2     1.69                                            Mexican
# 3     1.53  Bakery; Breakfast-Brunch; Japanese; Contempora...
# 4     1.69                                           American
# ..     ...                                                ...
# 133   1.65                                            Mexican
# 134   1.54  Organic-Healthy; Steaks; Middle_Eastern; Medit...
# 135   1.60                                            Mexican
# 136   1.78                                            Mexican
# 137   1.55                                           Pizzeria
#
#                     payment
# 0                      cash
# 1                      cash
# 2                      cash
# 3    cash; bank_debit_cards
# 4                      cash
# ..                      ...
# 133                    cash
# 134                    cash
# 135                    cash
# 136                    cash
# 137                    cash
#
# [138 rows x 21 columns]

# %% [markdown]
# ## Ratings

# %%
ratings_df = pd.read_csv(data_folder / 'rating_final.csv')
ratings_df.placeID = ratings_df.placeID.astype(str)
ratings_df
# Out:
#      userID placeID  rating  food_rating  service_rating
# 0     U1077  135085       2            2               2
# 1     U1077  135038       2            2               1
# 2     U1077  132825       2            2               2
# 3     U1077  135060       1            2               2
# 4     U1068  135104       1            1               2
# ...     ...     ...     ...          ...             ...
# 1156  U1043  132630       1            1               1
# 1157  U1011  132715       1            1               0
# 1158  U1068  132733       1            1               0
# 1159  U1068  132594       1            1               1
# 1160  U1068  132660       0            0               0
#
# [1161 rows x 5 columns]

# %% [markdown]
# # Populate data into Aito
# Now that we have all the data loaded and processed, we will upload it to your Aito instance

# %% [markdown]
# ## First, let's start with creating table schemas for each of the places, users, and ratings tables from their respective dataframes

# %% [markdown]
# ### Infer the Aito Table schema from the places data frame

# %%
places_schema = AitoTableSchema.infer_from_pandas_data_frame(places_df)
print(places_schema.to_json_string(indent=2))
# Out:
# {
#   "type": "table",
#   "columns": {
#     "placeID": {
#       "type": "String",
#       "nullable": false
#     },
#     "payment": {
#       "type": "String",
#       "nullable": true
#     },
#     "cuisine": {
#       "type": "String",
#       "nullable": true
#     },
#     "parking_lot": {
#       "type": "String",
#       "nullable": true
#     },
#     "latitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "longitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "the_geom_meter": {
#       "type": "String",
#       "nullable": true
#     },
#     "name": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "address": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "city": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": "whitespace"
#     },
#     "state": {
#       "type": "String",
#       "nullable": true
#     },
#     "country": {
#       "type": "String",
#       "nullable": true
#     },
#     "zip": {
#       "type": "String",
#       "nullable": true
#     },
#     "alcohol": {
#       "type": "String",
#       "nullable": true
#     },
#     "smoking_area": {
#       "type": "String",
#       "nullable": true
#     },
#     "dress_code": {
#       "type": "String",
#       "nullable": true
#     },
#     "accessibility": {
#       "type": "String",
#       "nullable": true
#     },
#     "price": {
#       "type": "String",
#       "nullable": true
#     },
#     "Rambience": {
#       "type": "String",
#       "nullable": true
#     },
#     "franchise": {
#       "type": "String",
#       "nullable": true
#     },
#     "area": {
#       "type": "String",
#       "nullable": true
#     },
#     "other_services": {
#       "type": "String",
#       "nullable": true
#     }
#   }
# }

# %% [markdown]
# #### Aito didn't do well to detect some fields to be semicolon delimited. Let's adjust a bit

# %%
for field in ('payment', 'cuisine', 'parking_lot'):
    places_schema[field].data_type = AitoTextType()
    places_schema[field].analyzer = AitoDelimiterAnalyzerSchema(delimiter=';')
print(places_schema.to_json_string(indent=2))
# Out:
# {
#   "type": "table",
#   "columns": {
#     "placeID": {
#       "type": "String",
#       "nullable": false
#     },
#     "payment": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "cuisine": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "parking_lot": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "latitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "longitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "the_geom_meter": {
#       "type": "String",
#       "nullable": true
#     },
#     "name": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "address": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "city": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": "whitespace"
#     },
#     "state": {
#       "type": "String",
#       "nullable": true
#     },
#     "country": {
#       "type": "String",
#       "nullable": true
#     },
#     "zip": {
#       "type": "String",
#       "nullable": true
#     },
#     "alcohol": {
#       "type": "String",
#       "nullable": true
#     },
#     "smoking_area": {
#       "type": "String",
#       "nullable": true
#     },
#     "dress_code": {
#       "type": "String",
#       "nullable": true
#     },
#     "accessibility": {
#       "type": "String",
#       "nullable": true
#     },
#     "price": {
#       "type": "String",
#       "nullable": true
#     },
#     "Rambience": {
#       "type": "String",
#       "nullable": true
#     },
#     "franchise": {
#       "type": "String",
#       "nullable": true
#     },
#     "area": {
#       "type": "String",
#       "nullable": true
#     },
#     "other_services": {
#       "type": "String",
#       "nullable": true
#     }
#   }
# }

# %%
print(places_schema.to_json_string(indent=2))
# Out:
# {
#   "type": "table",
#   "columns": {
#     "placeID": {
#       "type": "String",
#       "nullable": false
#     },
#     "payment": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "cuisine": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "parking_lot": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": ";",
#         "trimWhitespace": true
#       }
#     },
#     "latitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "longitude": {
#       "type": "Decimal",
#       "nullable": true
#     },
#     "the_geom_meter": {
#       "type": "String",
#       "nullable": true
#     },
#     "name": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "address": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": {
#         "type": "language",
#         "language": "spanish",
#         "useDefaultStopWords": false,
#         "customStopWords": [],
#         "customKeyWords": []
#       }
#     },
#     "city": {
#       "type": "Text",
#       "nullable": true,
#       "analyzer": "whitespace"
#     },
#     "state": {
#       "type": "String",
#       "nullable": true
#     },
#     "country": {
#       "type": "String",
#       "nullable": true
#     },
#     "zip": {
#       "type": "String",
#       "nullable": true
#     },
#     "alcohol": {
#       "type": "String",
#       "nullable": true
#     },
#     "smoking_area": {
#       "type": "String",
#       "nullable": true
#     },
#     "dress_code": {
#       "type": "String",
#       "nullable": true
#     },
#     "accessibility": {
#       "type": "String",
#       "nullable": true
#     },
#     "price": {
#       "type": "String",
#       "nullable": true
#     },
#     "Rambience": {
#       "type": "String",
#       "nullable": true
#     },
#     "franchise": {
#       "type": "String",
#       "nullable": true
#     },
#     "area": {
#       "type": "String",
#       "nullable": true
#     },
#     "other_services": {
#       "type": "String",
#       "nullable": true
#     }
#   }
# }

# %% [markdown]
# ### Infer the Aito Table schema from the user data frame

# %%
users_schema = AitoTableSchema.infer_from_pandas_data_frame(users_df)
print(users_schema.to_json_string(indent=2))
# Out:
# {
#   "type": "table",
#   "columns": {
#     "userID": {
#       "type": "String",
#       "nullable": false
#     },
#     "latitude": {
#       "type": "Decimal",
#       "nullable": false
#     },
#     "longitude": {
#       "type": "Decimal",
#       "nullable": false
#     },
#     "smoker": {
#       "type": "String",
#       "nullable": false
#     },
#     "drink_level": {
#       "type": "Text",
#       "nullable": false,
#       "analyzer": "whitespace"
#     },
#     "dress_preference": {
#       "type": "String",
#       "nullable": false
#     },
#     "ambience": {
#       "type": "String",
#       "nullable": false
#     },
#     "transport": {
#       "type": "String",
#       "nullable": false
#     },
#     "marital_status": {
#       "type": "String",
#       "nullable": false
#     },
#     "hijos": {
#       "type": "String",
#       "nullable": false
#     },
#     "birth_year": {
#       "type": "Int",
#       "nullable": false
#     },
#     "interest": {
#       "type": "String",
#       "nullable": false
#     },
#     "personality": {
#       "type": "Text",
#       "nullable": false,
#       "analyzer": {
#         "type": "delimiter",
#         "delimiter": "-",
#         "trimWhitespace": true
#       }
#     },
#     "religion": {
#       "type": "String",
#       "nullable": false
#     },
#     "activity": {
#       "type": "String",
#       "nullable": false
#     },
#     "color": {
#       "type": "String",
#       "nullable": false
#     },
#     "weight": {
#       "type": "Int",
#       "nullable": false
#     },
#     "budget": {
#       "type": "String",
#       "nullable": false
#     },
#     "height": {
#       "type": "Decimal",
#       "nullable": false
#     },
#     "cuisine": {
#       "type": "String",
#       "nullable": false
#     },
#     "payment": {
#       "type": "String",
#       "nullable": true
#     }
#   }
# }

# %% [markdown]
# #### Similarly, the users' cuisine and parking should be semicolon delimited

# %%
for field in ('payment', 'cuisine'):
    users_schema[field].data_type = AitoTextType()
    users_schema[field].analyzer = AitoDelimiterAnalyzerSchema(delimiter=';')

# %% [markdown]
# ### Infer the Aito Table Schema from the ratings data frame

# %%
ratings_schema = AitoTableSchema.infer_from_pandas_data_frame(ratings_df)
print(ratings_schema.to_json_string(indent=2))
# Out:
# {
#   "type": "table",
#   "columns": {
#     "userID": {
#       "type": "String",
#       "nullable": false
#     },
#     "placeID": {
#       "type": "String",
#       "nullable": false
#     },
#     "rating": {
#       "type": "Int",
#       "nullable": false
#     },
#     "food_rating": {
#       "type": "Int",
#       "nullable": false
#     },
#     "service_rating": {
#       "type": "Int",
#       "nullable": false
#     }
#   }
# }

# %% [markdown]
# #### Link the ratings to the places and the users table

# %%
ratings_schema['placeID'].link = AitoColumnLinkSchema('places', 'placeID')
ratings_schema['userID'].link = AitoColumnLinkSchema('users', 'userID')

# %% [markdown]
# #### We now have our db schema:

# %%
db_schema = AitoDatabaseSchema(tables={'users': users_schema, 'places': places_schema, 'ratings': ratings_schema})

# %%
print(db_schema.to_json_string(indent=2))
# Out:
# {
#   "schema": {
#     "users": {
#       "type": "table",
#       "columns": {
#         "userID": {
#           "type": "String",
#           "nullable": false
#         },
#         "latitude": {
#           "type": "Decimal",
#           "nullable": false
#         },
#         "longitude": {
#           "type": "Decimal",
#           "nullable": false
#         },
#         "smoker": {
#           "type": "String",
#           "nullable": false
#         },
#         "drink_level": {
#           "type": "Text",
#           "nullable": false,
#           "analyzer": "whitespace"
#         },
#         "dress_preference": {
#           "type": "String",
#           "nullable": false
#         },
#         "ambience": {
#           "type": "String",
#           "nullable": false
#         },
#         "transport": {
#           "type": "String",
#           "nullable": false
#         },
#         "marital_status": {
#           "type": "String",
#           "nullable": false
#         },
#         "hijos": {
#           "type": "String",
#           "nullable": false
#         },
#         "birth_year": {
#           "type": "Int",
#           "nullable": false
#         },
#         "interest": {
#           "type": "String",
#           "nullable": false
#         },
#         "personality": {
#           "type": "Text",
#           "nullable": false,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": "-",
#             "trimWhitespace": true
#           }
#         },
#         "religion": {
#           "type": "String",
#           "nullable": false
#         },
#         "activity": {
#           "type": "String",
#           "nullable": false
#         },
#         "color": {
#           "type": "String",
#           "nullable": false
#         },
#         "weight": {
#           "type": "Int",
#           "nullable": false
#         },
#         "budget": {
#           "type": "String",
#           "nullable": false
#         },
#         "height": {
#           "type": "Decimal",
#           "nullable": false
#         },
#         "cuisine": {
#           "type": "Text",
#           "nullable": false,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": ";",
#             "trimWhitespace": true
#           }
#         },
#         "payment": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": ";",
#             "trimWhitespace": true
#           }
#         }
#       }
#     },
#     "places": {
#       "type": "table",
#       "columns": {
#         "placeID": {
#           "type": "String",
#           "nullable": false
#         },
#         "payment": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": ";",
#             "trimWhitespace": true
#           }
#         },
#         "cuisine": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": ";",
#             "trimWhitespace": true
#           }
#         },
#         "parking_lot": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "delimiter",
#             "delimiter": ";",
#             "trimWhitespace": true
#           }
#         },
#         "latitude": {
#           "type": "Decimal",
#           "nullable": true
#         },
#         "longitude": {
#           "type": "Decimal",
#           "nullable": true
#         },
#         "the_geom_meter": {
#           "type": "String",
#           "nullable": true
#         },
#         "name": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "language",
#             "language": "spanish",
#             "useDefaultStopWords": false,
#             "customStopWords": [],
#             "customKeyWords": []
#           }
#         },
#         "address": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": {
#             "type": "language",
#             "language": "spanish",
#             "useDefaultStopWords": false,
#             "customStopWords": [],
#             "customKeyWords": []
#           }
#         },
#         "city": {
#           "type": "Text",
#           "nullable": true,
#           "analyzer": "whitespace"
#         },
#         "state": {
#           "type": "String",
#           "nullable": true
#         },
#         "country": {
#           "type": "String",
#           "nullable": true
#         },
#         "zip": {
#           "type": "String",
#           "nullable": true
#         },
#         "alcohol": {
#           "type": "String",
#           "nullable": true
#         },
#         "smoking_area": {
#           "type": "String",
#           "nullable": true
#         },
#         "dress_code": {
#           "type": "String",
#           "nullable": true
#         },
#         "accessibility": {
#           "type": "String",
#           "nullable": true
#         },
#         "price": {
#           "type": "String",
#           "nullable": true
#         },
#         "Rambience": {
#           "type": "String",
#           "nullable": true
#         },
#         "franchise": {
#           "type": "String",
#           "nullable": true
#         },
#         "area": {
#           "type": "String",
#           "nullable": true
#         },
#         "other_services": {
#           "type": "String",
#           "nullable": true
#         }
#       }
#     },
#     "ratings": {
#       "type": "table",
#       "columns": {
#         "userID": {
#           "type": "String",
#           "nullable": false,
#           "link": "users.userID"
#         },
#         "placeID": {
#           "type": "String",
#           "nullable": false,
#           "link": "places.placeID"
#         },
#         "rating": {
#           "type": "Int",
#           "nullable": false
#         },
#         "food_rating": {
#           "type": "Int",
#           "nullable": false
#         },
#         "service_rating": {
#           "type": "Int",
#           "nullable": false
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ## Finally, set up the credentials and upload the data into Aito

# %%
# Fill in your Aito instance credentials
AITO_INSTANCE_URL = 'https://team1junction.aito.app'
AITO_API_KEY = 'l9uG4dc5ha7BoqBcgT58S2Z7G7uq75ES9w6scxTM'

# %%
client = AitoClient(instance_url=AITO_INSTANCE_URL, api_key=AITO_API_KEY)

# %%
aito_api.create_database(client=client, schema=db_schema)

# %%
aito_api.upload_entries(client=client, table_name='places', entries=places_df.to_dict(orient='records'))
aito_api.upload_entries(client=client, table_name='users', entries=users_df.to_dict(orient='records'))
aito_api.upload_entries(client=client, table_name='ratings', entries=ratings_df.to_dict(orient='records'))

# %% [markdown]
# # Now, lets try some queries

# %% [markdown]
# ## Search for places that match an user's criteria
#
# Let's assumme that this user like Mexican cuisine and would like to pay by cash

# %%
query = {
    "from": "places",
    "where": {
        "cuisine": "Mexican",
        "payment": "cash"
    }
}
res = aito_api.generic_query(client=client, query=query)
print(res.to_json_string(indent=2))
# Out:
# {
#   "offset": 0,
#   "total": 147,
#   "hits": [
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "none",
#       "payment": "cash",
#       "placeID": "132578"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "none",
#       "payment": "cash",
#       "placeID": "132580"
#     },
#     {
#       "Rambience": "familiar",
#       "accessibility": "completely",
#       "alcohol": "No_Alcohol_Served",
#       "area": "closed",
#       "cuisine": "Mexican",
#       "dress_code": "informal",
#       "franchise": "t",
#       "latitude": 23.752364800000002,
#       "longitude": -99.16528790000001,
#       "name": "Gorditas Dona Tota",
#       "other_services": "none",
#       "parking_lot": "yes",
#       "payment": "cash",
#       "placeID": "132584",
#       "price": "medium",
#       "smoking_area": "not permitted",
#       "the_geom_meter": "0101000020957F000048C65BA7EF8157C177F2344D664E4941"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "public",
#       "payment": "cash",
#       "placeID": "132588"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "public",
#       "payment": "cash",
#       "placeID": "132593"
#     },
#     {
#       "Rambience": "familiar",
#       "accessibility": "completely",
#       "alcohol": "No_Alcohol_Served",
#       "area": "open",
#       "cuisine": "Mexican",
#       "dress_code": "informal",
#       "franchise": "f",
#       "latitude": 23.7521677,
#       "longitude": -99.16570899999999,
#       "name": "tacos de barbacoa enfrente del Tec",
#       "other_services": "none",
#       "parking_lot": "public",
#       "payment": "cash",
#       "placeID": "132594",
#       "price": "low",
#       "smoking_area": "not permitted",
#       "the_geom_meter": "0101000020957F00003AE4C6DBF48157C1CE38ECC1864E4941"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "none",
#       "payment": "cash",
#       "placeID": "132595"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "none",
#       "payment": "cash",
#       "placeID": "132596"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "public",
#       "payment": "cash",
#       "placeID": "132599"
#     },
#     {
#       "cuisine": "Mexican",
#       "parking_lot": "public",
#       "payment": "cash",
#       "placeID": "132602"
#     }
#   ]
# }

# %% [markdown]
# #### Pretty good but we want to return better results

# %% [markdown]
# ## This time, we would like to suggest a restaurant to an user based on the previous ratings

# %%
rec_query = {
    "from": "ratings",
    "where": {
        "userID": {
            "$and": [
                {"userID": "U1022"},
                {"userID": "U1026"}
            ]
        },
        "placeID": {
            "price": "high"
        }
    },
    "recommend": "placeID",
    "goal": {"rating": 2},
    "limit": 5
}

# %%
res = aito_api.recommend(client=client, query=rec_query)
res.json
# Out:
# {'offset': 0,
#  'total': 25,
#  'hits': [{'$p': 0.9244336662379592,
#    'Rambience': 'familiar',
#    'accessibility': 'no_accessibility',
#    'address': 'Ricardo Linares 107',
#    'alcohol': 'Wine-Beer',
#    'area': 'closed',
#    'city': 'Cuernavaca',
#    'country': 'Mexico',
#    'cuisine': 'International',
#    'dress_code': 'formal',
#    'franchise': 'f',
#    'latitude': 18.928798,
#    'longitude': -99.239513,
#    'name': 'Restaurant Las Mananitas',
#    'other_services': 'none',
#    'parking_lot': 'yes',
#    'placeID': '134986',
#    'price': 'high',
#    'smoking_area': 'none',
#    'state': 'Morelos',
#    'the_geom_meter': '0101000020957F00002A0D05E2D96D5AC1AB058CB1EC564A41'},
#   {'$p': 0.8847367370604847,
#    'Rambience': 'familiar',
#    'accessibility': 'no_accessibility',
#    'address': 'Venustiano Carranza 560 Centro',
#    'alcohol': 'Wine-Beer',
#    'area': 'closed',
#    'city': 'San Luis Potosi',
#    'country': 'Mexico',
#    'dress_code': 'casual',
#    'franchise': 'f',
#    'latitude': 22.151189000000002,
#    'longitude': -100.98179,
#    'name': 'Restaurante la Gran Via',
#    'other_services': 'none',
#    'parking_lot': 'yes',
#    'payment': 'cash;VISA;MasterCard-Eurocard;American_Express',
#    'placeID': '135045',
#    'price': 'high',
#    'smoking_area': 'none',
#    'state': 'SLP',
#    'the_geom_meter': '0101000020957F00000B6735CA004858C108FD525CB2A44B41',
#    'zip': '78000'},
#   {'$p': 0.8565059788045788,
#    'Rambience': 'familiar',
#    'accessibility': 'no_accessibility',
#    'address': 'Venustiano Carranza 2175 Jardin',
#    'alcohol': 'No_Alcohol_Served',
#    'area': 'closed',
#    'city': 'San Luis Potosi',
#    'country': 'Mexico',
#    'cuisine': 'Mexican',
#    'dress_code': 'informal',
#    'franchise': 'f',
#    'latitude': 22.148854,
#    'longitude': -101.008472,
#    'name': 'la Cochinita Pibil Restaurante Yucateco',
#    'other_services': 'none',
#    'parking_lot': 'yes',
#    'payment': 'cash;VISA;MasterCard-Eurocard;American_Express',
#    'placeID': '135055',
#    'price': 'high',
#    'smoking_area': 'section',
#    'state': 'SLP',
#    'the_geom_meter': '0101000020957F00006610DA0F9F4758C12ED00BA771AC4B41',
#    'zip': '78270'},
#   {'$p': 0.7992038844679102,
#    'Rambience': 'familiar',
#    'accessibility': 'no_accessibility',
#    'address': 'Ignacio Aldama 300 Centro',
#    'alcohol': 'Full_Bar',
#    'area': 'closed',
#    'city': 'San Luis Potosi',
#    'country': 'Mexico',
#    'cuisine': 'Bar;Bar_Pub_Brewery',
#    'dress_code': 'informal',
#    'franchise': 'f',
#    'latitude': 22.150980999999998,
#    'longitude': -100.977412,
#    'name': 'La Cantina Restaurante',
#    'other_services': 'none',
#    'parking_lot': 'none',
#    'payment': 'cash;VISA;MasterCard-Eurocard',
#    'placeID': '135052',
#    'price': 'high',
#    'smoking_area': 'none',
#    'state': 'SLP',
#    'the_geom_meter': '0101000020957F0000B72147F1274858C189A406ED75A34B41',
#    'zip': '78000'},
#   {'$p': 0.6993052173166198,
#    'Rambience': 'familiar',
#    'accessibility': 'no_accessibility',
#    'address': 'Capitan Caldera No. 420 Tequisqueapan',
#    'alcohol': 'Full_Bar',
#    'area': 'closed',
#    'city': 'San Luis Potosi',
#    'country': 'Mexico',
#    'cuisine': 'Bar;Bar_Pub_Brewery',
#    'dress_code': 'informal',
#    'franchise': 'f',
#    'latitude': 22.148665,
#    'longitude': -101.001273,
#    'name': 'la Cantina',
#    'other_services': 'none',
#    'parking_lot': 'none',
#    'placeID': '135026',
#    'price': 'high',
#    'smoking_area': 'none',
#    'state': 'SLP',
#    'the_geom_meter': '0101000020957F0000C75F8790D94758C1FF8BCA0567AA4B41',
#    'zip': '78250'}]}

# %% [markdown]
# ## This is just a scratch on the surface. Now it's your turn to explore Aito's capabilities and make the best restaurant recommendation app
